# %%
from pymongo.mongo_client import MongoClient
import pandas as pd
dbName = input("Enter the Database name: ")
dbPassword = input("Enter the Database password: ")
def loadData(dbName,dbPassword):
    client = MongoClient("mongodb+srv://"+dbName+":"+dbPassword+"@cluster0.3bxeryk.mongodb.net/?retryWrites=true&w=majority")
    db = client.delivery
    col = db.delivery
    cursor = col.find()
    dataList = list(cursor)
    df = pd.DataFrame(dataList)
    return df
data = loadData(dbName,dbPassword).drop(labels=['_id'],axis=1)

# %%
data
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 0      0xdb64      KNPRES14DEL02                 24.0  \
# 1      0x689b     PUNERES20DEL01                 33.0
# 2      0x6c6b    COIMBRES13DEL01                 37.0
# 3       0xbff      SURRES16DEL02                 36.0
# 4      0x4bda      HYDRES17DEL02                 35.0
# ...       ...                ...                  ...
# 45579  0x6607    COIMBRES16DEL02                 26.0
# 45580  0x1163      SURRES06DEL02                  NaN
# 45581  0x1b0d      HYDRES08DEL03                 26.0
# 45582  0xd641      AGRRES16DEL01                 21.0
# 45583  0x4f8d     CHENRES08DEL03                 30.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 0                          4.7            26.463504             80.372929  \
# 1                          4.2            18.592718             73.773572
# 2                          5.0            11.003669             76.976494
# 3                          4.1            21.160437             72.774209
# 4                          5.0            17.451976             78.385883
# ...                        ...                  ...                   ...
# 45579                      4.2            11.010375             76.952950
# 45580                      NaN            21.185047             72.808590
# 45581                      5.0            17.438263             78.397865
# 45582                      4.6             0.000000              0.000000
# 45583                      4.9            13.022394             80.242439
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 0                       26.593504                    80.502929  14-02-2022  \
# 1                       18.702718                    73.883572  16-03-2022
# 2                       11.013669                    76.986494  11-03-2022
# 3                       21.210437                    72.824209  05-03-2022
# 4                       17.471976                    78.405883  01-04-2022
# ...                           ...                          ...         ...
# 45579                   11.030375                    76.972950  01-04-2022
# 45580                   21.205047                    72.828590  03-04-2022
# 45581                   17.528263                    78.487865  23-03-2022
# 45582                    0.070000                     0.070000  16-02-2022
# 45583                   13.052394                    80.272439  11-03-2022
#
#        Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 0            19:50             20:05                Fog                  Jam  \
# 1            20:30             20:40         Sandstorms                  Jam
# 2            08:15             08:30         Sandstorms                  Low
# 3            22:35             22:40             Stormy                  Low
# 4            09:45             09:55              Sunny                  Low
# ...            ...               ...                ...                  ...
# 45579  0.416666667             10:10              Windy                  Low
# 45580          NaN             10:50              Windy                  Low
# 45581        18:50             18:55             Cloudy               Medium
# 45582        19:55             20:10              Windy                  Jam
# 45583        23:50          24:05:00             Cloudy                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries
# 0                      1         Snack         scooter                  1.0  \
# 1                      2         Snack      motorcycle                  1.0
# 2                      1         Snack      motorcycle                  1.0
# 3                      0        Drinks      motorcycle                  1.0
# 4                      2         Snack         scooter                  1.0
# ...                  ...           ...             ...                  ...
# 45579                  0        Drinks      motorcycle                  1.0
# 45580                  2          Meal         scooter                  0.0
# 45581                  0          Meal      motorcycle                  1.0
# 45582                  0        Buffet      motorcycle                  1.0
# 45583                  1        Drinks         scooter                  0.0
#
#       Festival           City  Time_taken (min)
# 0           No  Metropolitian                41
# 1           No  Metropolitian                40
# 2           No  Metropolitian                20
# 3           No          Urban                22
# 4           No          Urban                11
# ...        ...            ...               ...
# 45579       No          Urban                18
# 45580       No          Urban                12
# 45581       No  Metropolitian                32
# 45582       No  Metropolitian                36
# 45583       No  Metropolitian                16
#
# [45584 rows x 20 columns]

# %%
import pandas as pd

# %%
# data = pd.read_csv("https://raw.githubusercontent.com/AKISHPOTHURI/DataScience/main/Dataset/online_order.csv")
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xdb64      KNPRES14DEL02                 24.0                      4.7  \
# 1  0x689b     PUNERES20DEL01                 33.0                      4.2
# 2  0x6c6b    COIMBRES13DEL01                 37.0                      5.0
# 3   0xbff      SURRES16DEL02                 36.0                      4.1
# 4  0x4bda      HYDRES17DEL02                 35.0                      5.0
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            26.463504             80.372929                   26.593504  \
# 1            18.592718             73.773572                   18.702718
# 2            11.003669             76.976494                   11.013669
# 3            21.160437             72.774209                   21.210437
# 4            17.451976             78.385883                   17.471976
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    80.502929  14-02-2022       19:50             20:05  \
# 1                    73.883572  16-03-2022       20:30             20:40
# 2                    76.986494  11-03-2022       08:15             08:30
# 3                    72.824209  05-03-2022       22:35             22:40
# 4                    78.405883  01-04-2022       09:45             09:55
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  1         Snack  \
# 1         Sandstorms                  Jam                  2         Snack
# 2         Sandstorms                  Low                  1         Snack
# 3             Stormy                  Low                  0        Drinks
# 4              Sunny                  Low                  2         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City
# 0         scooter                  1.0       No  Metropolitian  \
# 1      motorcycle                  1.0       No  Metropolitian
# 2      motorcycle                  1.0       No  Metropolitian
# 3      motorcycle                  1.0       No          Urban
# 4         scooter                  1.0       No          Urban
#
#    Time_taken (min)
# 0                41
# 1                40
# 2                20
# 3                22
# 4                11

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
#  12  Road_traffic_density         44983 non-null  object
#  13  Vehicle_condition            45584 non-null  int64
#  14  Type_of_order                45584 non-null  object
#  15  Type_of_vehicle              45584 non-null  object
#  16  multiple_deliveries          44591 non-null  float64
#  17  Festival                     45356 non-null  object
#  18  City                         44384 non-null  object
#  19  Time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 7.0+ MB

# %%
data.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# count         43730.000000             43676.000000         45584.000000  \
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude
# count          45584.000000                45584.000000  \
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# 25%               73.170000                   12.988453
# 50%               75.897963                   18.633934
# 75%               78.044095                   22.785049
# max               88.433452                   31.054057
#
#        Delivery_location_longitude  Vehicle_condition  multiple_deliveries
# count                 45584.000000       45584.000000         44591.000000  \
# mean                     70.844161           1.023385             0.744635
# std                      21.120578           0.839055             0.572510
# min                       0.010000           0.000000             0.000000
# 25%                      73.280000           0.000000             0.000000
# 50%                      76.002574           1.000000             1.000000
# 75%                      78.107044           2.000000             1.000000
# max                      88.563452           3.000000             3.000000
#
#        Time_taken (min)
# count      45584.000000
# mean          26.293963
# std            9.384298
# min           10.000000
# 25%           19.000000
# 50%           26.000000
# 75%           32.000000
# max           54.000000

# %%
data['Vehicle_condition'].unique()
# Out:
# array([2, 1, 0, 3], dtype=int64)

# %%
data['Delivery_person_Ratings'].unique()
# Out:
# array([4.2, 4.7, 4.3, 4.5, 4. , 4.9, 4.1, 5. , 4.8, 3.5, 4.6, nan, 4.4,
#        3.8, 3.9, 3.7, 2.6, 2.5, 3.6, 3.1, 2.7, 1. , 3.2, 3.3, 6. , 3.4,
#        2.8, 2.9, 3. ])

# %%
data[data['Delivery_person_Ratings'].isnull()] # we have 1908 null values
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 33      0x4f0      MUMRES17DEL02                  NaN  \
# 65      0xa9f     BANGRES13DEL01                  NaN
# 111     0x6e2      VADRES06DEL01                  NaN
# 118    0xd0e5      KOLRES17DEL03                 23.0
# 131    0x1ec7     PUNERES05DEL03                  NaN
# ...       ...                ...                  ...
# 45499  0x426b      HYDRES06DEL01                  NaN
# 45509   0x863     INDORES05DEL01                  NaN
# 45510  0xd0be      AGRRES07DEL01                  NaN
# 45517  0x1ed1      JAPRES18DEL01                  NaN
# 45557  0x1163      SURRES06DEL02                  NaN
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 33                         NaN            19.121999             72.908493  \
# 65                         NaN            12.935662             77.614130
# 111                        NaN            22.312790             73.170283
# 118                        NaN            22.569358             88.433452
# 131                        NaN            18.543626             73.905101
# ...                        ...                  ...                   ...
# 45499                      NaN            17.455894             78.375467
# 45509                      NaN            22.727021             75.884167
# 45510                      NaN            27.160934             78.044095
# 45517                      NaN            26.913987             75.752891
# 45557                      NaN            21.185047             72.808590
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 33                      19.201999                    72.988493  06-04-2022  \
# 65                      12.975662                    77.654130  11-03-2022
# 111                     22.422790                    73.280283  02-04-2022
# 118                     22.599358                    88.463452  17-02-2022
# 131                     18.573626                    73.935101  09-03-2022
# ...                           ...                          ...         ...
# 45499                   17.525894                    78.445467  23-03-2022
# 45509                   22.737021                    75.894167  19-03-2022
# 45510                   27.170934                    78.054095  13-02-2022
# 45517                   27.023987                    75.862891  27-03-2022
# 45557                   21.205047                    72.828590  03-04-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 33            NaN             18:35             Cloudy               Medium  \
# 65            NaN             15:30                NaN                  NaN
# 111           NaN             18:25                NaN                  NaN
# 118         23:25             23:35              Sunny                  Low
# 131           NaN             23:40             Stormy                  Low
# ...           ...               ...                ...                  ...
# 45499       17:55              0.75                Fog               Medium
# 45509         NaN             11:40                NaN                  NaN
# 45510         NaN             09:05                NaN                  NaN
# 45517       20:35             20:45             Cloudy                  Jam
# 45557         NaN             10:50              Windy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 33                     1        Drinks           scooter                  1.0  \
# 65                     1        Drinks           scooter                  0.0
# 111                    3         Snack  electric_scooter                  0.0
# 118                    0        Drinks        motorcycle                  0.0
# 131                    2         Snack           scooter                  0.0
# ...                  ...           ...               ...                  ...
# 45499                  0          Meal        motorcycle                  1.0
# 45509                  3         Snack  electric_scooter                  0.0
# 45510                  3          Meal  electric_scooter                  1.0
# 45517                  2         Snack           scooter                  0.0
# 45557                  2          Meal           scooter                  0.0
#
#       Festival           City  Time_taken (min)
# 33          No  Metropolitian                33
# 65          No  Metropolitian                19
# 111         No  Metropolitian                25
# 118         No  Metropolitian                15
# 131         No            NaN                19
# ...        ...            ...               ...
# 45499       No          Urban                36
# 45509       No  Metropolitian                25
# 45510       No          Urban                17
# 45517       No  Metropolitian                48
# 45557       No          Urban                12
#
# [1908 rows x 20 columns]

# %%
data['multiple_deliveries'].unique()
# Out:
# array([ 3.,  1.,  0., nan,  2.])

# %%
data[data['multiple_deliveries'].isnull()] #we have 993 rows of null values.
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 8      0x6f67      HYDRES14DEL01                 34.0  \
# 77     0x837c     PUNERES14DEL02                 39.0
# 86     0xb437      SURRES16DEL01                 25.0
# 126    0x894e     BANGRES12DEL02                 28.0
# 135    0x4008     SURRES010DEL02                 29.0
# ...       ...                ...                  ...
# 45038   0xac9   RANCHIRES12DEL02                 36.0
# 45066  0xb8a5      VADRES08DEL03                 23.0
# 45071  0x7324     CHENRES11DEL03                 29.0
# 45142  0x954a     INDORES02DEL02                 22.0
# 45247  0x62aa     BANGRES16DEL02                 22.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 8                          4.9            17.426228             78.407495  \
# 77                         4.8            18.516216             73.842527
# 86                         5.0            21.160437             72.774209
# 126                        4.8            12.939496             77.625999
# 135                        4.6            21.171060             72.789292
# ...                        ...                  ...                   ...
# 45038                      4.8             0.000000              0.000000
# 45066                      4.7             0.000000              0.000000
# 45071                      4.6            13.064181             80.236442
# 45142                      4.8            22.651847             75.881991
# 45247                      4.9            13.029198             77.570997
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 8                       17.496228                    78.477495  20-03-2022  \
# 77                      18.566216                    73.892527  03-03-2022
# 86                      21.270437                    72.884209  18-03-2022
# 126                     12.989496                    77.675999  24-03-2022
# 135                     21.251060                    72.869292  12-03-2022
# ...                           ...                          ...         ...
# 45038                    0.020000                     0.020000  11-03-2022
# 45066                    0.090000                     0.090000  31-03-2022
# 45071                   13.094181                    80.266442  03-03-2022
# 45142                   22.701847                    75.931991  28-03-2022
# 45247                   13.159198                    77.700997  12-03-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 8           20:40             20:50             Cloudy                  Jam  \
# 77          21:55             22:10             Stormy                  Jam
# 86          20:25             20:40             Stormy                  Jam
# 126         23:10             23:15                Fog                  Low
# 135         19:40             19:55              Sunny                  Jam
# ...           ...               ...                ...                  ...
# 45038       08:15             08:30              Sunny                  Low
# 45066       23:20             23:35         Sandstorms                  Low
# 45071       17:40             17:55                Fog               Medium
# 45142       20:45             0.875             Stormy                  Jam
# 45247       19:45             19:50              Sunny                  Jam
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 8                      0         Snack        motorcycle                  NaN  \
# 77                     1          Meal        motorcycle                  NaN
# 86                     1          Meal        motorcycle                  NaN
# 126                    1        Drinks        motorcycle                  NaN
# 135                    2          Meal  electric_scooter                  NaN
# ...                  ...           ...               ...                  ...
# 45038                  1         Snack           scooter                  NaN
# 45066                  2         Snack           scooter                  NaN
# 45071                  1        Drinks           scooter                  NaN
# 45142                  1         Snack           scooter                  NaN
# 45247                  2        Drinks  electric_scooter                  NaN
#
#       Festival           City  Time_taken (min)
# 8           No  Metropolitian                41
# 77          No  Metropolitian                28
# 86          No  Metropolitian                15
# 126         No  Metropolitian                18
# 135         No  Metropolitian                17
# ...        ...            ...               ...
# 45038       No          Urban                15
# 45066       No          Urban                17
# 45071       No          Urban                15
# 45142       No          Urban                14
# 45247       No  Metropolitian                24
#
# [993 rows x 20 columns]

# %%
data[data['Delivery_person_Age'].isnull()] #there are 1854 rows of null values.
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 33      0x4f0      MUMRES17DEL02                  NaN  \
# 65      0xa9f     BANGRES13DEL01                  NaN
# 111     0x6e2      VADRES06DEL01                  NaN
# 131    0x1ec7     PUNERES05DEL03                  NaN
# 170    0x1b58      JAPRES03DEL01                  NaN
# ...       ...                ...                  ...
# 45499  0x426b      HYDRES06DEL01                  NaN
# 45509   0x863     INDORES05DEL01                  NaN
# 45510  0xd0be      AGRRES07DEL01                  NaN
# 45517  0x1ed1      JAPRES18DEL01                  NaN
# 45557  0x1163      SURRES06DEL02                  NaN
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 33                         NaN            19.121999             72.908493  \
# 65                         NaN            12.935662             77.614130
# 111                        NaN            22.312790             73.170283
# 131                        NaN            18.543626             73.905101
# 170                        NaN            26.913483             75.803139
# ...                        ...                  ...                   ...
# 45499                      NaN            17.455894             78.375467
# 45509                      NaN            22.727021             75.884167
# 45510                      NaN            27.160934             78.044095
# 45517                      NaN            26.913987             75.752891
# 45557                      NaN            21.185047             72.808590
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 33                      19.201999                    72.988493  06-04-2022  \
# 65                      12.975662                    77.654130  11-03-2022
# 111                     22.422790                    73.280283  02-04-2022
# 131                     18.573626                    73.935101  09-03-2022
# 170                     26.983483                    75.873139  12-03-2022
# ...                           ...                          ...         ...
# 45499                   17.525894                    78.445467  23-03-2022
# 45509                   22.737021                    75.894167  19-03-2022
# 45510                   27.170934                    78.054095  13-02-2022
# 45517                   27.023987                    75.862891  27-03-2022
# 45557                   21.205047                    72.828590  03-04-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 33            NaN             18:35             Cloudy               Medium  \
# 65            NaN             15:30                NaN                  NaN
# 111           NaN             18:25                NaN                  NaN
# 131           NaN             23:40             Stormy                  Low
# 170           NaN             17:50         Sandstorms               Medium
# ...           ...               ...                ...                  ...
# 45499       17:55              0.75                Fog               Medium
# 45509         NaN             11:40                NaN                  NaN
# 45510         NaN             09:05                NaN                  NaN
# 45517       20:35             20:45             Cloudy                  Jam
# 45557         NaN             10:50              Windy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 33                     1        Drinks           scooter                  1.0  \
# 65                     1        Drinks           scooter                  0.0
# 111                    3         Snack  electric_scooter                  0.0
# 131                    2         Snack           scooter                  0.0
# 170                    0        Drinks        motorcycle                  0.0
# ...                  ...           ...               ...                  ...
# 45499                  0          Meal        motorcycle                  1.0
# 45509                  3         Snack  electric_scooter                  0.0
# 45510                  3          Meal  electric_scooter                  1.0
# 45517                  2         Snack           scooter                  0.0
# 45557                  2          Meal           scooter                  0.0
#
#       Festival           City  Time_taken (min)
# 33          No  Metropolitian                33
# 65          No  Metropolitian                19
# 111         No  Metropolitian                25
# 131         No            NaN                19
# 170         No  Metropolitian                43
# ...        ...            ...               ...
# 45499       No          Urban                36
# 45509       No  Metropolitian                25
# 45510       No          Urban                17
# 45517       No  Metropolitian                48
# 45557       No          Urban                12
#
# [1854 rows x 20 columns]

# %%
data[data['Time_Orderd'].isnull()]#there are 1731 rows of null values.
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 33      0x4f0      MUMRES17DEL02                  NaN  \
# 65      0xa9f     BANGRES13DEL01                  NaN
# 111     0x6e2      VADRES06DEL01                  NaN
# 131    0x1ec7     PUNERES05DEL03                  NaN
# 170    0x1b58      JAPRES03DEL01                  NaN
# ...       ...                ...                  ...
# 45396  0xc7ed      KNPRES20DEL03                  NaN
# 45495   0x461     BANGRES07DEL02                  NaN
# 45509   0x863     INDORES05DEL01                  NaN
# 45510  0xd0be      AGRRES07DEL01                  NaN
# 45557  0x1163      SURRES06DEL02                  NaN
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 33                         NaN            19.121999             72.908493  \
# 65                         NaN            12.935662             77.614130
# 111                        NaN            22.312790             73.170283
# 131                        NaN            18.543626             73.905101
# 170                        NaN            26.913483             75.803139
# ...                        ...                  ...                   ...
# 45396                      NaN            26.470000             80.350000
# 45495                      NaN           -12.978453            -77.643685
# 45509                      NaN            22.727021             75.884167
# 45510                      NaN            27.160934             78.044095
# 45557                      NaN            21.185047             72.808590
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 33                      19.201999                    72.988493  06-04-2022  \
# 65                      12.975662                    77.654130  11-03-2022
# 111                     22.422790                    73.280283  02-04-2022
# 131                     18.573626                    73.935101  09-03-2022
# 170                     26.983483                    75.873139  12-03-2022
# ...                           ...                          ...         ...
# 45396                   26.610000                    80.490000  12-02-2022
# 45495                   12.998453                    77.663685  17-03-2022
# 45509                   22.737021                    75.894167  19-03-2022
# 45510                   27.170934                    78.054095  13-02-2022
# 45557                   21.205047                    72.828590  03-04-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 33            NaN             18:35             Cloudy               Medium  \
# 65            NaN             15:30                NaN                  NaN
# 111           NaN             18:25                NaN                  NaN
# 131           NaN             23:40             Stormy                  Low
# 170           NaN             17:50         Sandstorms               Medium
# ...           ...               ...                ...                  ...
# 45396         NaN             19:25              Windy                  Jam
# 45495         NaN             09:30                NaN                  NaN
# 45509         NaN             11:40                NaN                  NaN
# 45510         NaN             09:05                NaN                  NaN
# 45557         NaN             10:50              Windy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 33                     1        Drinks           scooter                  1.0  \
# 65                     1        Drinks           scooter                  0.0
# 111                    3         Snack  electric_scooter                  0.0
# 131                    2         Snack           scooter                  0.0
# 170                    0        Drinks        motorcycle                  0.0
# ...                  ...           ...               ...                  ...
# 45396                  1        Drinks           scooter                  1.0
# 45495                  3          Meal           scooter                  1.0
# 45509                  3         Snack  electric_scooter                  0.0
# 45510                  3          Meal  electric_scooter                  1.0
# 45557                  2          Meal           scooter                  0.0
#
#       Festival           City  Time_taken (min)
# 33          No  Metropolitian                33
# 65          No  Metropolitian                19
# 111         No  Metropolitian                25
# 131         No            NaN                19
# 170         No  Metropolitian                43
# ...        ...            ...               ...
# 45396       No  Metropolitian                18
# 45495       No            NaN                24
# 45509       No  Metropolitian                25
# 45510       No          Urban                17
# 45557       No          Urban                12
#
# [1731 rows x 20 columns]

# %%
data[data['Weather_conditions'].isnull()] #there are 616 rows of null values
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 65      0xa9f     BANGRES13DEL01                  NaN  \
# 111     0x6e2      VADRES06DEL01                  NaN
# 241    0x1b50     PUNERES16DEL01                  NaN
# 339     0x4c1     BANGRES13DEL02                  NaN
# 416    0xc003      DEHRES13DEL02                  NaN
# ...       ...                ...                  ...
# 45323  0x2950      VADRES04DEL02                 50.0
# 45385   0xdc4   RANCHIRES02DEL03                  NaN
# 45495   0x461     BANGRES07DEL02                  NaN
# 45509   0x863     INDORES05DEL01                  NaN
# 45510  0xd0be      AGRRES07DEL01                  NaN
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 65                         NaN            12.935662             77.614130  \
# 111                        NaN            22.312790             73.170283
# 241                        NaN            18.536718             73.830327
# 339                        NaN            12.935662             77.614130
# 416                        NaN           -30.366322            -78.070453
# ...                        ...                  ...                   ...
# 45323                      6.0             0.000000              0.000000
# 45385                      NaN             0.000000              0.000000
# 45495                      NaN           -12.978453            -77.643685
# 45509                      NaN            22.727021             75.884167
# 45510                      NaN            27.160934             78.044095
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 65                      12.975662                    77.654130  11-03-2022  \
# 111                     22.422790                    73.280283  02-04-2022
# 241                     18.646718                    73.940327  08-03-2022
# 339                     13.065662                    77.744130  02-03-2022
# 416                     30.496322                    78.200453  18-02-2022
# ...                           ...                          ...         ...
# 45323                    0.020000                     0.020000  19-03-2022
# 45385                    0.030000                     0.030000  05-03-2022
# 45495                   12.998453                    77.663685  17-03-2022
# 45509                   22.737021                    75.894167  19-03-2022
# 45510                   27.170934                    78.054095  13-02-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 65            NaN             15:30                NaN                  NaN  \
# 111           NaN             18:25                NaN                  NaN
# 241           NaN             21:25                NaN                  NaN
# 339           NaN          24:05:00                NaN                  NaN
# 416           NaN             22:30                NaN                  NaN
# ...           ...               ...                ...                  ...
# 45323         NaN             10:40                NaN                  NaN
# 45385         NaN             17:25                NaN                  NaN
# 45495         NaN             09:30                NaN                  NaN
# 45509         NaN             11:40                NaN                  NaN
# 45510         NaN             09:05                NaN                  NaN
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 65                     1        Drinks           scooter                  0.0  \
# 111                    3         Snack  electric_scooter                  0.0
# 241                    3        Buffet        motorcycle                  1.0
# 339                    3        Drinks           scooter                  1.0
# 416                    3         Snack           scooter                  1.0
# ...                  ...           ...               ...                  ...
# 45323                  3        Drinks  electric_scooter                  1.0
# 45385                  3        Buffet           bicycle                  1.0
# 45495                  3          Meal           scooter                  1.0
# 45509                  3         Snack  electric_scooter                  0.0
# 45510                  3          Meal  electric_scooter                  1.0
#
#       Festival           City  Time_taken (min)
# 65          No  Metropolitian                19
# 111         No  Metropolitian                25
# 241        Yes          Urban                43
# 339         No  Metropolitian                26
# 416         No  Metropolitian                20
# ...        ...            ...               ...
# 45323       No          Urban                28
# 45385       No  Metropolitian                21
# 45495       No            NaN                24
# 45509       No  Metropolitian                25
# 45510       No          Urban                17
#
# [616 rows x 20 columns]

# %%
data[data['Road_traffic_density'].isnull()] #there are 601 rows of null values
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 65      0xa9f     BANGRES13DEL01                  NaN  \
# 111     0x6e2      VADRES06DEL01                  NaN
# 241    0x1b50     PUNERES16DEL01                  NaN
# 339     0x4c1     BANGRES13DEL02                  NaN
# 416    0xc003      DEHRES13DEL02                  NaN
# ...       ...                ...                  ...
# 45323  0x2950      VADRES04DEL02                 50.0
# 45385   0xdc4   RANCHIRES02DEL03                  NaN
# 45495   0x461     BANGRES07DEL02                  NaN
# 45509   0x863     INDORES05DEL01                  NaN
# 45510  0xd0be      AGRRES07DEL01                  NaN
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 65                         NaN            12.935662             77.614130  \
# 111                        NaN            22.312790             73.170283
# 241                        NaN            18.536718             73.830327
# 339                        NaN            12.935662             77.614130
# 416                        NaN           -30.366322            -78.070453
# ...                        ...                  ...                   ...
# 45323                      6.0             0.000000              0.000000
# 45385                      NaN             0.000000              0.000000
# 45495                      NaN           -12.978453            -77.643685
# 45509                      NaN            22.727021             75.884167
# 45510                      NaN            27.160934             78.044095
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 65                      12.975662                    77.654130  11-03-2022  \
# 111                     22.422790                    73.280283  02-04-2022
# 241                     18.646718                    73.940327  08-03-2022
# 339                     13.065662                    77.744130  02-03-2022
# 416                     30.496322                    78.200453  18-02-2022
# ...                           ...                          ...         ...
# 45323                    0.020000                     0.020000  19-03-2022
# 45385                    0.030000                     0.030000  05-03-2022
# 45495                   12.998453                    77.663685  17-03-2022
# 45509                   22.737021                    75.894167  19-03-2022
# 45510                   27.170934                    78.054095  13-02-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 65            NaN             15:30                NaN                  NaN  \
# 111           NaN             18:25                NaN                  NaN
# 241           NaN             21:25                NaN                  NaN
# 339           NaN          24:05:00                NaN                  NaN
# 416           NaN             22:30                NaN                  NaN
# ...           ...               ...                ...                  ...
# 45323         NaN             10:40                NaN                  NaN
# 45385         NaN             17:25                NaN                  NaN
# 45495         NaN             09:30                NaN                  NaN
# 45509         NaN             11:40                NaN                  NaN
# 45510         NaN             09:05                NaN                  NaN
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 65                     1        Drinks           scooter                  0.0  \
# 111                    3         Snack  electric_scooter                  0.0
# 241                    3        Buffet        motorcycle                  1.0
# 339                    3        Drinks           scooter                  1.0
# 416                    3         Snack           scooter                  1.0
# ...                  ...           ...               ...                  ...
# 45323                  3        Drinks  electric_scooter                  1.0
# 45385                  3        Buffet           bicycle                  1.0
# 45495                  3          Meal           scooter                  1.0
# 45509                  3         Snack  electric_scooter                  0.0
# 45510                  3          Meal  electric_scooter                  1.0
#
#       Festival           City  Time_taken (min)
# 65          No  Metropolitian                19
# 111         No  Metropolitian                25
# 241        Yes          Urban                43
# 339         No  Metropolitian                26
# 416         No  Metropolitian                20
# ...        ...            ...               ...
# 45323       No          Urban                28
# 45385       No  Metropolitian                21
# 45495       No            NaN                24
# 45509       No  Metropolitian                25
# 45510       No          Urban                17
#
# [601 rows x 20 columns]

# %%
data[data['multiple_deliveries'].isnull()] #there are 993 rows of null values
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 8      0x6f67      HYDRES14DEL01                 34.0  \
# 77     0x837c     PUNERES14DEL02                 39.0
# 86     0xb437      SURRES16DEL01                 25.0
# 126    0x894e     BANGRES12DEL02                 28.0
# 135    0x4008     SURRES010DEL02                 29.0
# ...       ...                ...                  ...
# 45038   0xac9   RANCHIRES12DEL02                 36.0
# 45066  0xb8a5      VADRES08DEL03                 23.0
# 45071  0x7324     CHENRES11DEL03                 29.0
# 45142  0x954a     INDORES02DEL02                 22.0
# 45247  0x62aa     BANGRES16DEL02                 22.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 8                          4.9            17.426228             78.407495  \
# 77                         4.8            18.516216             73.842527
# 86                         5.0            21.160437             72.774209
# 126                        4.8            12.939496             77.625999
# 135                        4.6            21.171060             72.789292
# ...                        ...                  ...                   ...
# 45038                      4.8             0.000000              0.000000
# 45066                      4.7             0.000000              0.000000
# 45071                      4.6            13.064181             80.236442
# 45142                      4.8            22.651847             75.881991
# 45247                      4.9            13.029198             77.570997
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 8                       17.496228                    78.477495  20-03-2022  \
# 77                      18.566216                    73.892527  03-03-2022
# 86                      21.270437                    72.884209  18-03-2022
# 126                     12.989496                    77.675999  24-03-2022
# 135                     21.251060                    72.869292  12-03-2022
# ...                           ...                          ...         ...
# 45038                    0.020000                     0.020000  11-03-2022
# 45066                    0.090000                     0.090000  31-03-2022
# 45071                   13.094181                    80.266442  03-03-2022
# 45142                   22.701847                    75.931991  28-03-2022
# 45247                   13.159198                    77.700997  12-03-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 8           20:40             20:50             Cloudy                  Jam  \
# 77          21:55             22:10             Stormy                  Jam
# 86          20:25             20:40             Stormy                  Jam
# 126         23:10             23:15                Fog                  Low
# 135         19:40             19:55              Sunny                  Jam
# ...           ...               ...                ...                  ...
# 45038       08:15             08:30              Sunny                  Low
# 45066       23:20             23:35         Sandstorms                  Low
# 45071       17:40             17:55                Fog               Medium
# 45142       20:45             0.875             Stormy                  Jam
# 45247       19:45             19:50              Sunny                  Jam
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 8                      0         Snack        motorcycle                  NaN  \
# 77                     1          Meal        motorcycle                  NaN
# 86                     1          Meal        motorcycle                  NaN
# 126                    1        Drinks        motorcycle                  NaN
# 135                    2          Meal  electric_scooter                  NaN
# ...                  ...           ...               ...                  ...
# 45038                  1         Snack           scooter                  NaN
# 45066                  2         Snack           scooter                  NaN
# 45071                  1        Drinks           scooter                  NaN
# 45142                  1         Snack           scooter                  NaN
# 45247                  2        Drinks  electric_scooter                  NaN
#
#       Festival           City  Time_taken (min)
# 8           No  Metropolitian                41
# 77          No  Metropolitian                28
# 86          No  Metropolitian                15
# 126         No  Metropolitian                18
# 135         No  Metropolitian                17
# ...        ...            ...               ...
# 45038       No          Urban                15
# 45066       No          Urban                17
# 45071       No          Urban                15
# 45142       No          Urban                14
# 45247       No  Metropolitian                24
#
# [993 rows x 20 columns]

# %%
data[data['Festival'].isnull()] #there are 228 rows of null values
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 1392   0xd08f      BHPRES20DEL02                 30.0  \
# 1397    0x8f4     INDORES19DEL02                  NaN
# 1406   0x60a2     CHENRES03DEL01                 24.0
# 1577   0x51ea    COIMBRES05DEL01                 25.0
# 1614   0x1752      HYDRES18DEL02                 29.0
# ...       ...                ...                  ...
# 44879  0x1fb6     BANGRES15DEL03                 28.0
# 44956  0xe034      GOARES16DEL01                 25.0
# 45118  0x7d89      MUMRES17DEL02                 26.0
# 45146  0x3d07     CHENRES15DEL01                 26.0
# 45164  0x9e82     CHENRES08DEL02                 25.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 1392                       4.9            23.235123             77.398886  \
# 1397                       NaN            22.745536             75.893106
# 1406                       4.5            13.091809             80.219104
# 1577                       4.6            11.022169             76.999594
# 1614                       4.9            17.450851             78.379347
# ...                        ...                  ...                   ...
# 44879                      4.6            12.975377             77.696664
# 44956                      4.9            15.498603             73.826911
# 45118                      4.5            19.121999             72.908493
# 45146                      4.8            13.026286             80.275235
# 45164                      4.8            13.022394             80.242439
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 1392                    23.255123                    77.418886  17-02-2022  \
# 1397                    22.765536                    75.913106  30-03-2022
# 1406                    13.101809                    80.229104  15-03-2022
# 1577                    11.132169                    77.109594  12-03-2022
# 1614                    17.470851                    78.399347  01-03-2022
# ...                           ...                          ...         ...
# 44879                   13.035377                    77.756664  30-03-2022
# 44956                   15.538603                    73.866911  15-02-2022
# 45118                   19.171999                    72.958493  13-03-2022
# 45146                   13.136286                    80.385235  02-03-2022
# 45164                   13.102394                    80.322439  27-03-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 1392        09:40             09:50              Sunny                  Low  \
# 1397          NaN             08:40             Cloudy                  Low
# 1406        09:40             09:45         Sandstorms                  Low
# 1577        22:35             22:45             Stormy                  Low
# 1614        0.375             09:05              Windy                  Low
# ...           ...               ...                ...                  ...
# 44879       17:55              0.75             Cloudy               Medium
# 44956       12:25             12:30              Sunny                 High
# 45118       19:30             19:45              Sunny                  Jam
# 45146       22:25             22:40             Stormy                  Low
# 45164       22:40             22:45              Windy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 1392                   2        Drinks           scooter                  1.0  \
# 1397                   2          Meal  electric_scooter                  0.0
# 1406                   2        Drinks        motorcycle                  0.0
# 1577                   2          Meal           scooter                  1.0
# 1614                   2         Snack        motorcycle                  0.0
# ...                  ...           ...               ...                  ...
# 44879                  2          Meal           scooter                  1.0
# 44956                  1        Drinks           scooter                  0.0
# 45118                  1          Meal        motorcycle                  1.0
# 45146                  1        Drinks        motorcycle                  0.0
# 45164                  1          Meal           scooter                  0.0
#
#       Festival           City  Time_taken (min)
# 1392       NaN  Metropolitian                12
# 1397       NaN  Metropolitian                10
# 1406       NaN          Urban                11
# 1577       NaN  Metropolitian                14
# 1614       NaN  Metropolitian                13
# ...        ...            ...               ...
# 44879      NaN  Metropolitian                13
# 44956      NaN          Urban                10
# 45118      NaN  Metropolitian                14
# 45146      NaN          Urban                12
# 45164      NaN  Metropolitian                10
#
# [228 rows x 20 columns]

# %%
data[data['City'].isnull()] #there are 1200 rows of null values
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 49     0xb002      JAPRES14DEL01                 32.0  \
# 107    0x4beb      MYSRES08DEL01                 20.0
# 131    0x1ec7     PUNERES05DEL03                  NaN
# 141    0x81a5     BANGRES04DEL03                 26.0
# 197    0x7bfb    COIMBRES11DEL02                 20.0
# ...       ...                ...                  ...
# 45408  0x5a9a      SURRES05DEL01                 24.0
# 45487  0x250b     CHENRES09DEL02                 37.0
# 45495   0x461     BANGRES07DEL02                  NaN
# 45541  0x7483     INDORES04DEL01                 23.0
# 45571  0xbb2b      MYSRES08DEL02                 34.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 49                         4.5            26.888420             75.800689  \
# 107                        4.8            12.297954             76.665169
# 131                        NaN            18.543626             73.905101
# 141                        4.4            12.980410             77.640489
# 197                        4.5            11.001753             76.986241
# ...                        ...                  ...                   ...
# 45408                      4.5            21.175104             72.804342
# 45487                      4.9            13.044694             80.261470
# 45495                      NaN           -12.978453            -77.643685
# 45541                      4.6            22.753659             75.903365
# 45571                      4.9            12.297954             76.665169
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 49                      26.898420                    75.810689  26-03-2022  \
# 107                     12.307954                    76.675169  30-03-2022
# 131                     18.573626                    73.935101  09-03-2022
# 141                     13.040410                    77.700489  07-03-2022
# 197                     11.021753                    77.006241  03-04-2022
# ...                           ...                          ...         ...
# 45408                   21.185104                    72.814342  19-03-2022
# 45487                   13.094694                    80.311470  26-03-2022
# 45495                   12.998453                    77.663685  17-03-2022
# 45541                   22.763659                    75.913365  11-03-2022
# 45571                   12.317954                    76.685169  05-04-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 49          09:25             09:40              Windy                  Low  \
# 107         09:15             09:30             Cloudy                  Low
# 131           NaN             23:40             Stormy                  Low
# 141         23:20             23:30         Sandstorms                  Low
# 197         08:50             0.375                Fog                  Low
# ...           ...               ...                ...                  ...
# 45408       08:50             09:05             Cloudy                  Low
# 45487           1          24:15:00              Sunny                  Low
# 45495         NaN             09:30                NaN                  NaN
# 45541       08:40             08:45             Cloudy                  Low
# 45571       09:10             09:15         Sandstorms                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries
# 49                     2        Buffet         scooter                  0.0  \
# 107                    0        Drinks      motorcycle                  0.0
# 131                    2         Snack         scooter                  0.0
# 141                    0        Buffet      motorcycle                  0.0
# 197                    1         Snack      motorcycle                  0.0
# ...                  ...           ...             ...                  ...
# 45408                  1        Drinks      motorcycle                  0.0
# 45487                  2         Snack         scooter                  1.0
# 45495                  3          Meal         scooter                  1.0
# 45541                  2         Snack         scooter                  1.0
# 45571                  1         Snack         scooter                  1.0
#
#       Festival City  Time_taken (min)
# 49          No  NaN                20
# 107         No  NaN                16
# 131         No  NaN                19
# 141         No  NaN                23
# 197         No  NaN                11
# ...        ...  ...               ...
# 45408       No  NaN                16
# 45487       No  NaN                12
# 45495       No  NaN                24
# 45541       No  NaN                12
# 45571       No  NaN                26
#
# [1200 rows x 20 columns]

# %% [markdown]
# # Null values:
#
# Delivery_person_Age   -       1854
#
# Delivery_person_Ratings   -   1908
#
# Time_Orderd               -   1731
#
# Weather_conditions       -    616
#
# Road_traffic_density      -   601
#
#
# multiple_deliveries       -   993
#
# Festival                 -    228
#
# City                      -   1200

# %%
data[data.isna().any(axis=1)]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 8      0x6f67      HYDRES14DEL01                 34.0  \
# 33      0x4f0      MUMRES17DEL02                  NaN
# 49     0xb002      JAPRES14DEL01                 32.0
# 65      0xa9f     BANGRES13DEL01                  NaN
# 77     0x837c     PUNERES14DEL02                 39.0
# ...       ...                ...                  ...
# 45510  0xd0be      AGRRES07DEL01                  NaN
# 45517  0x1ed1      JAPRES18DEL01                  NaN
# 45541  0x7483     INDORES04DEL01                 23.0
# 45557  0x1163      SURRES06DEL02                  NaN
# 45571  0xbb2b      MYSRES08DEL02                 34.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 8                          4.9            17.426228             78.407495  \
# 33                         NaN            19.121999             72.908493
# 49                         4.5            26.888420             75.800689
# 65                         NaN            12.935662             77.614130
# 77                         4.8            18.516216             73.842527
# ...                        ...                  ...                   ...
# 45510                      NaN            27.160934             78.044095
# 45517                      NaN            26.913987             75.752891
# 45541                      4.6            22.753659             75.903365
# 45557                      NaN            21.185047             72.808590
# 45571                      4.9            12.297954             76.665169
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 8                       17.496228                    78.477495  20-03-2022  \
# 33                      19.201999                    72.988493  06-04-2022
# 49                      26.898420                    75.810689  26-03-2022
# 65                      12.975662                    77.654130  11-03-2022
# 77                      18.566216                    73.892527  03-03-2022
# ...                           ...                          ...         ...
# 45510                   27.170934                    78.054095  13-02-2022
# 45517                   27.023987                    75.862891  27-03-2022
# 45541                   22.763659                    75.913365  11-03-2022
# 45557                   21.205047                    72.828590  03-04-2022
# 45571                   12.317954                    76.685169  05-04-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 8           20:40             20:50             Cloudy                  Jam  \
# 33            NaN             18:35             Cloudy               Medium
# 49          09:25             09:40              Windy                  Low
# 65            NaN             15:30                NaN                  NaN
# 77          21:55             22:10             Stormy                  Jam
# ...           ...               ...                ...                  ...
# 45510         NaN             09:05                NaN                  NaN
# 45517       20:35             20:45             Cloudy                  Jam
# 45541       08:40             08:45             Cloudy                  Low
# 45557         NaN             10:50              Windy                  Low
# 45571       09:10             09:15         Sandstorms                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 8                      0         Snack        motorcycle                  NaN  \
# 33                     1        Drinks           scooter                  1.0
# 49                     2        Buffet           scooter                  0.0
# 65                     1        Drinks           scooter                  0.0
# 77                     1          Meal        motorcycle                  NaN
# ...                  ...           ...               ...                  ...
# 45510                  3          Meal  electric_scooter                  1.0
# 45517                  2         Snack           scooter                  0.0
# 45541                  2         Snack           scooter                  1.0
# 45557                  2          Meal           scooter                  0.0
# 45571                  1         Snack           scooter                  1.0
#
#       Festival           City  Time_taken (min)
# 8           No  Metropolitian                41
# 33          No  Metropolitian                33
# 49          No            NaN                20
# 65          No  Metropolitian                19
# 77          No  Metropolitian                28
# ...        ...            ...               ...
# 45510       No          Urban                17
# 45517       No  Metropolitian                48
# 45541       No            NaN                12
# 45557       No          Urban                12
# 45571       No            NaN                26
#
# [4225 rows x 20 columns]

# %%
data.count()
# Out:
# ID                             45584
# Delivery_person_ID             45584
# Delivery_person_Age            43730
# Delivery_person_Ratings        43676
# Restaurant_latitude            45584
# Restaurant_longitude           45584
# Delivery_location_latitude     45584
# Delivery_location_longitude    45584
# Order_Date                     45584
# Time_Orderd                    43853
# Time_Order_picked              45584
# Weather_conditions             44968
# Road_traffic_density           44983
# Vehicle_condition              45584
# Type_of_order                  45584
# Type_of_vehicle                45584
# multiple_deliveries            44591
# Festival                       45356
# City                           44384
# Time_taken (min)               45584
# dtype: int64

# %%
df = data.loc[data.isnull().sum(1)>=3]

# %%
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 33      0x4f0      MUMRES17DEL02                  NaN  \
# 65      0xa9f     BANGRES13DEL01                  NaN
# 111     0x6e2      VADRES06DEL01                  NaN
# 131    0x1ec7     PUNERES05DEL03                  NaN
# 170    0x1b58      JAPRES03DEL01                  NaN
# ...       ...                ...                  ...
# 45396  0xc7ed      KNPRES20DEL03                  NaN
# 45495   0x461     BANGRES07DEL02                  NaN
# 45509   0x863     INDORES05DEL01                  NaN
# 45510  0xd0be      AGRRES07DEL01                  NaN
# 45557  0x1163      SURRES06DEL02                  NaN
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 33                         NaN            19.121999             72.908493  \
# 65                         NaN            12.935662             77.614130
# 111                        NaN            22.312790             73.170283
# 131                        NaN            18.543626             73.905101
# 170                        NaN            26.913483             75.803139
# ...                        ...                  ...                   ...
# 45396                      NaN            26.470000             80.350000
# 45495                      NaN           -12.978453            -77.643685
# 45509                      NaN            22.727021             75.884167
# 45510                      NaN            27.160934             78.044095
# 45557                      NaN            21.185047             72.808590
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date
# 33                      19.201999                    72.988493  06-04-2022  \
# 65                      12.975662                    77.654130  11-03-2022
# 111                     22.422790                    73.280283  02-04-2022
# 131                     18.573626                    73.935101  09-03-2022
# 170                     26.983483                    75.873139  12-03-2022
# ...                           ...                          ...         ...
# 45396                   26.610000                    80.490000  12-02-2022
# 45495                   12.998453                    77.663685  17-03-2022
# 45509                   22.737021                    75.894167  19-03-2022
# 45510                   27.170934                    78.054095  13-02-2022
# 45557                   21.205047                    72.828590  03-04-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density
# 33            NaN             18:35             Cloudy               Medium  \
# 65            NaN             15:30                NaN                  NaN
# 111           NaN             18:25                NaN                  NaN
# 131           NaN             23:40             Stormy                  Low
# 170           NaN             17:50         Sandstorms               Medium
# ...           ...               ...                ...                  ...
# 45396         NaN             19:25              Windy                  Jam
# 45495         NaN             09:30                NaN                  NaN
# 45509         NaN             11:40                NaN                  NaN
# 45510         NaN             09:05                NaN                  NaN
# 45557         NaN             10:50              Windy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries
# 33                     1        Drinks           scooter                  1.0  \
# 65                     1        Drinks           scooter                  0.0
# 111                    3         Snack  electric_scooter                  0.0
# 131                    2         Snack           scooter                  0.0
# 170                    0        Drinks        motorcycle                  0.0
# ...                  ...           ...               ...                  ...
# 45396                  1        Drinks           scooter                  1.0
# 45495                  3          Meal           scooter                  1.0
# 45509                  3         Snack  electric_scooter                  0.0
# 45510                  3          Meal  electric_scooter                  1.0
# 45557                  2          Meal           scooter                  0.0
#
#       Festival           City  Time_taken (min)
# 33          No  Metropolitian                33
# 65          No  Metropolitian                19
# 111         No  Metropolitian                25
# 131         No            NaN                19
# 170         No  Metropolitian                43
# ...        ...            ...               ...
# 45396       No  Metropolitian                18
# 45495       No            NaN                24
# 45509       No  Metropolitian                25
# 45510       No          Urban                17
# 45557       No          Urban                12
#
# [1749 rows x 20 columns]

# %%
data1 = pd.concat([data, df, df]).drop_duplicates(keep=False)

# %%
data1.count() #here we have to manage the multiple_deliveries, Festival, City,Delivery persons age, 
#delivery persons rating columns.
# Out:
# ID                             43835
# Delivery_person_ID             43835
# Delivery_person_Age            43638
# Delivery_person_Ratings        43584
# Restaurant_latitude            43835
# Restaurant_longitude           43835
# Delivery_location_latitude     43835
# Delivery_location_longitude    43835
# Order_Date                     43835
# Time_Orderd                    43835
# Time_Order_picked              43835
# Weather_conditions             43835
# Road_traffic_density           43835
# Vehicle_condition              43835
# Type_of_order                  43835
# Type_of_vehicle                43835
# multiple_deliveries            42902
# Festival                       43618
# City                           42700
# Time_taken (min)               43835
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age             197
# Delivery_person_Ratings         251
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             933
# Festival                        217
# City                           1135
# Time_taken (min)                  0
# dtype: int64

# %%
import seaborn as sns
sns.set_style('whitegrid')
sns.distplot(data1['Delivery_person_Age'], kde = True, color ='red', bins = 30)
# Out:
# C:\Users\akish.pothuri\AppData\Local\Temp\ipykernel_25340\2164831683.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['Delivery_person_Age'], kde = True, color ='red', bins = 30)
# <Axes: xlabel='Delivery_person_Age', ylabel='Density'>

# %%
sns.set_style('whitegrid')
sns.distplot(data1['Delivery_person_Ratings'], kde = True, color ='red', bins = 30)
# Out:
# C:\Users\akish.pothuri\AppData\Local\Temp\ipykernel_25340\3740354887.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['Delivery_person_Ratings'], kde = True, color ='red', bins = 30)
# <Axes: xlabel='Delivery_person_Ratings', ylabel='Density'>

# %%
sns.set_style('whitegrid')
sns.distplot(data1['multiple_deliveries'], kde = True, color ='red', bins = 30)
# Out:
# C:\Users\akish.pothuri\AppData\Local\Temp\ipykernel_25340\793245996.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['multiple_deliveries'], kde = True, color ='red', bins = 30)
# <Axes: xlabel='multiple_deliveries', ylabel='Density'>

# %%
data1['Festival'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
pd.value_counts(data1['Festival'])
# Out:
# Festival
# No     42761
# Yes      857
# Name: count, dtype: int64

# %%
data1 = data1[data1['City'].notna()]

# %%
data1[data1['City'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min)]
# Index: []

# %%
data1.count()
# Out:
# ID                             42700
# Delivery_person_ID             42700
# Delivery_person_Age            42503
# Delivery_person_Ratings        42450
# Restaurant_latitude            42700
# Restaurant_longitude           42700
# Delivery_location_latitude     42700
# Delivery_location_longitude    42700
# Order_Date                     42700
# Time_Orderd                    42700
# Time_Order_picked              42700
# Weather_conditions             42700
# Road_traffic_density           42700
# Vehicle_condition              42700
# Type_of_order                  42700
# Type_of_vehicle                42700
# multiple_deliveries            41799
# Festival                       42500
# City                           42700
# Time_taken (min)               42700
# dtype: int64

# %%
import numpy as np
data1['Festival'].fillna("No", inplace = True) # 98% of the column has No as a value 
data1['Delivery_person_Ratings'].fillna(round(np.mean(data1['Delivery_person_Ratings']),1), inplace = True)
data1['Delivery_person_Age'].fillna(round(np.mean(data1['Delivery_person_Age'])), inplace = True)
data1['multiple_deliveries'].fillna(round(np.mean(data1['multiple_deliveries'])), inplace=True)

# %%
data1.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# dtype: int64
